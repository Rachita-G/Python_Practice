# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachita-G/Python_Practice/blob/main/Projects/Working_with_Covid_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Covid India

# %%
data=pd.read_csv('C:\\Users\\sanjana grover\\Desktop\\RACHITA\\Python\\Data\\covid_19_india.csv')
data.head(30)
# Out:
#     Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0     1  30/01/20  6:00 PM               Kerala                       1
# 1     2  31/01/20  6:00 PM               Kerala                       1
# 2     3  01/02/20  6:00 PM               Kerala                       2
# 3     4  02/02/20  6:00 PM               Kerala                       3
# 4     5  03/02/20  6:00 PM               Kerala                       3
# 5     6  04/02/20  6:00 PM               Kerala                       3
# 6     7  05/02/20  6:00 PM               Kerala                       3
# 7     8  06/02/20  6:00 PM               Kerala                       3
# 8     9  07/02/20  6:00 PM               Kerala                       3
# 9    10  08/02/20  6:00 PM               Kerala                       3
# 10   11  09/02/20  6:00 PM               Kerala                       3
# 11   12  10/02/20  6:00 PM               Kerala                       3
# ...

# %%
data[State/UnionTerritory==]

# %%
data.groupby('State/UnionTerritory')[['Cured','Deaths','Confirmed']].sum()
# Out:
#                                             Cured  Deaths  Confirmed
# State/UnionTerritory
# Andaman and Nicobar Islands                  3294       0       4798
# Andhra Pradesh                             298156    8367     606956
# Arunachal Pradesh                            1856      27       6813
# Assam                                      179208     583     304923
# Bihar                                      276539    3012     426408
# Cases being reassigned to states                0       0     342062
# Chandigarh                                  16904     329      24319
# Chhattisgarh                                68510     442     102649
# Dadar Nagar Haveli                             14       0        186
# Dadra and Nagar Haveli and Daman and Diu     2639       1       6634
# Daman & Diu                                     0       0          2
# Delhi                                     1876159   95218    3156662
# ...

# %% [markdown]
# # Covid Global

# %%
rc=pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
dt=pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')

# %%
rc['Province/State'].isnull().sum()
# Out:
# 199

# %%
rc.shape , dt.shape
# Out:
# ((274, 1107), (289, 1107))
